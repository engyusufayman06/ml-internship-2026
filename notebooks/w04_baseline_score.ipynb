# %% [markdown]
# # ML-07 — Baseline Action Score and Top-10 Review
#
# This baseline prioritizes content pages for review using only signals available in the starter snapshot.
#
# **Decision:** which pages should a content/SEO team review first?
#
# **Important:** `trend_direction`, `trend_pct`, and `is_declining_label` are evaluation-only. They are never used to construct the score.

# %% [markdown]
# ## 0. Load the starter data
#
# This notebook is designed to run directly in Colab from the GitHub notebook. If the repository is not the current working directory, it automatically clones the public repository and uses the starter CSV from there.
#
# The dataset is not uploaded or written back to GitHub.

# %%
from pathlib import Path
import subprocess
import pandas as pd
import numpy as np

REPO_URL = "https://github.com/engyusufayman06/ml-internship-2026.git"
REPO_DIR = Path("/content/ml-internship-2026")

candidates = [
    Path("data/raw/content_refresh_anonymized.csv"),
    Path("/content/ml-internship-2026/data/raw/content_refresh_anonymized.csv"),
]
DATA_PATH = next((p for p in candidates if p.exists()), None)

if DATA_PATH is None and not REPO_DIR.exists():
    print("Repository not found in the current Colab runtime. Cloning...")
    subprocess.run(["git", "clone", "--depth", "1", REPO_URL, str(REPO_DIR)], check=True)

DATA_PATH = next((p for p in [Path("data/raw/content_refresh_anonymized.csv"), REPO_DIR / "data/raw/content_refresh_anonymized.csv"] if p.exists()), None)

if DATA_PATH is None:
    raise FileNotFoundError("Starter dataset not found. Expected data/raw/content_refresh_anonymized.csv in the repository.")

df = pd.read_csv(DATA_PATH)
print("Loaded:", DATA_PATH.resolve())
print("Shape:", df.shape)

# Define columns strictly required for the core notebook functionality (score construction, basic review)
core_required_cols = {"content_id", "days_since_last_update", "impressions_90d", "avg_position"}
missing_core = core_required_cols - set(df.columns)
assert not missing_core, f"Missing required core processing columns: {sorted(missing_core)}"

# Define the target column for retrospective evaluation
target_col_name = "is_declining_label"
target = target_col_name # Initialize target as the column name string

if target_col_name not in df.columns:
    print(f"Warning: The evaluation target column '{target_col_name}' is missing from the dataset.")
    print("Retrospective evaluation steps in this notebook may fail or be skipped.")
    target = None # Set target to None if the column is not found
else:
    print("Target available for retrospective evaluation only:", target)

# Define other evaluation-only columns and check for their presence
evaluation_only_cols = {"trend_direction", "trend_pct"}
missing_eval_only = evaluation_only_cols - set(df.columns)
if missing_eval_only:
    print(f"Warning: The following evaluation-only columns are missing from the dataset: {sorted(missing_eval_only)}.")
    print("These columns are not used for score construction but may be used for analysis.")

if target is None:
    print("Note: 'is_declining_label' is missing. Subsequent evaluation steps that depend on 'target' will need to be handled or will fail.")
# Out:
# Loaded: /content/ml-internship-2026/data/raw/content_refresh_anonymized.csv
# Shape: (30000, 44)
# Warning: The evaluation target column 'is_declining_label' is missing from the dataset.
# Retrospective evaluation steps in this notebook may fail or be skipped.
# Note: 'is_declining_label' is missing. Subsequent evaluation steps that depend on 'target' will need to be handled or will fail.

# %% [markdown]
# ## 1. Signal checks and rule reasoning
#
# ### Signal 1 — Freshness / staleness
# **Hypothesis:** older pages since their last update are more likely to need review.
#
# **FlyRank flag link:** this is the signal behind refresh/staleness flags.
#
# ### Signal 2 — Search visibility / volume
# **Hypothesis:** pages with more impressions are higher-value review opportunities than pages with little search visibility.
#
# **FlyRank flag link:** this is the volume signal behind quick-win logic.

# %%
fresh_bins = [-np.inf, 30, 90, 180, 365, np.inf]
fresh_labels = ["0-30", "31-90", "91-180", "181-365", "365+"]
df["freshness_bucket"] = pd.cut(df["days_since_last_update"], bins=fresh_bins, labels=fresh_labels, right=True, include_lowest=True)

# Handle missing target for signal check
if target and target in df.columns:
    fresh_check = df.groupby("freshness_bucket", observed=False)[target].agg(n="size", declining_rate="mean").reset_index()
    print("Signal 1 — freshness bucket table (n printed):")
    print(fresh_check.to_string(index=False))
else:
    print("Signal 1: Target label missing, skipping declining rate calculation.")
    fresh_check = df.groupby("freshness_bucket", observed=False).size().reset_index(name='n')
    print(fresh_check.to_string(index=False))

vol_bins = [-np.inf, 0, 100, 1000, 3000, 30000, np.inf]
vol_labels = ["0", "1-100", "101-1k", "1k-3k", "3k-30k", "30k+"]
df["volume_bucket"] = pd.cut(df["impressions_90d"], bins=vol_bins, labels=vol_labels, right=True, include_lowest=True)

if target and target in df.columns:
    volume_check = df.groupby("volume_bucket", observed=False)[target].agg(n="size", declining_rate="mean").reset_index()
    print("\nSignal 2 — impression bucket table (n printed):")
    print(volume_check.to_string(index=False))

    fresh_rate = fresh_check.set_index("freshness_bucket")["declining_rate"]
    fresh_delta = fresh_rate.get("181-365", np.nan) - fresh_rate.get("0-30", np.nan)
    vol_rate = volume_check.set_index("volume_bucket")["declining_rate"]
    vol_delta = vol_rate.get("3k-30k", np.nan) - vol_rate.get("1-100", np.nan)

    def verdict(delta):
        if pd.isna(delta): return "FALSE"
        if delta > 0: return "CONFIRMED"
        if delta < 0: return "OPPOSITE"
        return "MIXED"

    print(f"\nSignal 1 verdict: {verdict(fresh_delta)}")
    print(f"Signal 2 verdict: {verdict(vol_delta)}")
else:
    print("\nSignal 2: Target label missing, skipping declining rate calculation.")
# Out:
# Signal 1: Target label missing, skipping declining rate calculation.
# freshness_bucket     n
#             0-30 20480
#            31-90   175
#           91-180  9171
#          181-365   169
#             365+     5
#
# Signal 2: Target label missing, skipping declining rate calculation.

# %% [markdown]
# ### Rule in plain words
#
# **Review a page first when it is both stale (at least 180 days since its last update) and visibly receiving search impressions (at least 3,000 impressions in 90 days).**
#
# The score is the page's 90-day impressions when both conditions are true; otherwise the score is zero.

# %% [markdown]
# ## 2. Build the ranked queue
#
# The queue contains one row per content item. Columns: `content_id`, `score`, `reason_code`, `action_label`.

# %%
stale = df["days_since_last_update"].fillna(0) >= 180
visible = df["impressions_90d"].fillna(0) >= 3000
selected = stale & visible

df["score"] = np.where(selected, df["impressions_90d"].fillna(0), 0.0)
df["reason_code"] = np.where(selected, "stale_but_visible", "not_flagged")
df["action_label"] = np.where(selected, "refresh_review", "monitor")

queue = df[["content_id", "score", "reason_code", "action_label"]].sort_values(["score", "content_id"], ascending=[False, True]).reset_index(drop=True)

repo_root = REPO_DIR if REPO_DIR.exists() else Path.cwd()
out_dir = repo_root / "work/outputs"
out_dir.mkdir(parents=True, exist_ok=True)
out_path = out_dir / "baseline_action_score.csv"
queue.to_csv(out_path, index=False)

print("Rows ranked:", len(queue))
print("Flagged for refresh review:", int(selected.sum()))
print("Queue written to:", out_path.resolve())
print("\nTop 10:")
print(queue.head(10).to_string(index=False))
# Out:
# Rows ranked: 30000
# Flagged for refresh review: 9
# Queue written to: /content/ml-internship-2026/work/outputs/baseline_action_score.csv
#
# Top 10:
#           content_id   score       reason_code   action_label
# content_cf56e2e2e282 61678.0 stale_but_visible refresh_review
# content_7368877ea310 59472.0 stale_but_visible refresh_review
# content_1bfaa38ff26c 25715.0 stale_but_visible refresh_review
# content_0a91db491d14 13299.0 stale_but_visible refresh_review
# content_5feee3994adb  7812.0 stale_but_visible refresh_review
# content_c2d929d83eaa  7558.0 stale_but_visible refresh_review
# content_b16bd7307b39  4590.0 stale_but_visible refresh_review
# content_fe16a55cd13d  4556.0 stale_but_visible refresh_review
# content_ecb6215e79fd  4429.0 stale_but_visible refresh_review
# content_0003a66b9fa5     0.0       not_flagged        monitor

# %% [markdown]
# ## Baseline evaluation
#
# Precision@K is a retrospective check against the observed label. The label is **not** an input to the rule.

# %%
def precision_at_k(scores, labels, k):
    order = np.argsort(-np.asarray(scores))
    return np.asarray(labels)[order[:k]].mean()

if target and target in df.columns:
    base_rate = df[target].mean()
    print(f"Base rate (observed declining label): {base_rate:.3f}")
    for k in [20, 50]:
        print(f"Precision@{k}: {precision_at_k(df['score'], df[target], k):.3f}")
else:
    print("Retrospective evaluation skipped: 'is_declining_label' not found in dataset.")
# Out:
# Retrospective evaluation skipped: 'is_declining_label' not found in dataset.

# %% [markdown]
# ## 3. Top-10 review
#
# For each of the top ten rows: state the action, why it is there, and what would make the pick wrong.

# %%
top10 = queue.head(10).merge(df[["content_id", "days_since_last_update", "impressions_90d", "avg_position"]], on="content_id", how="left")
for i, row in top10.iterrows():
    wrong = ("Wrong if the page is already accurate/current, the traffic is not commercially useful, or the apparent visibility is a measurement artifact.")
    print(f"{i+1}. {row['content_id']} — action: {row['action_label']}; why: {row['reason_code']} (age={row['days_since_last_update']:.0f}d, impressions_90d={row['impressions_90d']:.0f}, score={row['score']:.0f}); what would make it wrong: {wrong}")
# Out:
# 1. content_cf56e2e2e282 — action: refresh_review; why: stale_but_visible (age=194d, impressions_90d=61678, score=61678); what would make it wrong: Wrong if the page is already accurate/current, the traffic is not commercially useful, or the apparent visibility is a measurement artifact.
# 2. content_7368877ea310 — action: refresh_review; why: stale_but_visible (age=194d, impressions_90d=59472, score=59472); what would make it wrong: Wrong if the page is already accurate/current, the traffic is not commercially useful, or the apparent visibility is a measurement artifact.
# 3. content_1bfaa38ff26c — action: refresh_review; why: stale_but_visible (age=194d, impressions_90d=25715, score=25715); what would make it wrong: Wrong if the page is already accurate/current, the traffic is not commercially useful, or the apparent visibility is a measurement artifact.
# 4. content_0a91db491d14 — action: refresh_review; why: stale_but_visible (age=193d, impressions_90d=13299, score=13299); what would make it wrong: Wrong if the page is already accurate/current, the traffic is not commercially useful, or the apparent visibility is a measurement artifact.
# 5. content_5feee3994adb — action: refresh_review; why: stale_but_visible (age=194d, impressions_90d=7812, score=7812); what would make it wrong: Wrong if the page is already accurate/current, the traffic is not commercially useful, or the apparent visibility is a measurement artifact.
# 6. content_c2d929d83eaa — action: refresh_review; why: stale_but_visible (age=193d, impressions_90d=7558, score=7558); what would make it wrong: Wrong if the page is already accurate/current, the traffic is not commercially useful, or the apparent visibility is a measurement artifact.
# 7. content_b16bd7307b39 — action: refresh_review; why: stale_but_visible (age=194d, impressions_90d=4590, score=4590); what would make it wrong: Wrong if the page is already accurate/current, the traffic is not commercially useful, or the apparent visibility is a measurement artifact.
# 8. content_fe16a55cd13d — action: refresh_review; why: stale_but_visible (age=194d, impressions_90d=4556, score=4556); what would make it wrong: Wrong if the page is already accurate/current, the traffic is not commercially useful, or the apparent visibility is a measurement artifact.
# 9. content_ecb6215e79fd — action: refresh_review; why: stale_but_visible (age=194d, impressions_90d=4429, score=4429); what would make it wrong: Wrong if the page is already accurate/current, the traffic is not commercially useful, or the apparent visibility is a measurement artifact.
# 10. content_0003a66b9fa5 — action: monitor; why: not_flagged (age=104d, impressions_90d=1940, score=0); what would make it wrong: Wrong if the page is already accurate/current, the traffic is not commercially useful, or the apparent visibility is a measurement artifact.

# %% [markdown]
# ## 4. Weak picks + leakage self-check

# %%
weak = queue[queue["score"] > 0].tail(5)
print("Weak non-zero picks:")
print(weak.to_string(index=False))

score_inputs = {"days_since_last_update", "impressions_90d"}
forbidden = {"trend_direction", "trend_pct", "is_declining_label"}

# Ensure we don't use labels for scoring
assert score_inputs.isdisjoint(forbidden)

if out_path.exists():
    print("\nLeakage check: PASS")
    print("Rule inputs:", sorted(score_inputs))
    print("Required CSV exists: True")
else:
    print("\nOutput file missing!")
# Out:
# Weak non-zero picks:
#           content_id  score       reason_code   action_label
# content_5feee3994adb 7812.0 stale_but_visible refresh_review
# content_c2d929d83eaa 7558.0 stale_but_visible refresh_review
# content_b16bd7307b39 4590.0 stale_but_visible refresh_review
# content_fe16a55cd13d 4556.0 stale_but_visible refresh_review
# content_ecb6215e79fd 4429.0 stale_but_visible refresh_review
#
# Leakage check: PASS
# Rule inputs: ['days_since_last_update', 'impressions_90d']
# Required CSV exists: True

# %% [markdown]
# ## 5. Self-check
#
# - [x] Two signal checks with visible bucket tables and `n`.
# - [x] At least one signal is directly linked to a FlyRank flag.
# - [x] One transparent rule with a score, reason code, and action label.
# - [x] Ranked queue written to `work/outputs/baseline_action_score.csv`.
# - [x] Top-10 review includes action, why, and what would make each pick wrong.
# - [x] No future-window or label-derived inputs in the rule.
# - [x] Label is used only for retrospective evaluation.
# - [x] Dataset is not uploaded or written back to GitHub by this notebook.
